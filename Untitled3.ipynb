# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.animation as animation

fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15
    y += np.pi / 30
    im = ax.imshow(f(x, y), animated=True)
    #if i == 0:
        #ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
#
ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()

# %%
conda install -c conda-forge ffmpeg
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /global/homes/g/ginella/.conda/envs/warpx
#
#   added / updated specs:
#     - ffmpeg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     ffmpeg-7.0.1               | gpl_h3589c0a_102         9.6 MB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gnutls-3.7.9               |       hb077bed_0         1.9 MB  conda-forge
#     libass-0.17.1              |       h8fe9dca_1         124 KB  conda-forge
#     libdrm-2.4.122             |       h4ab18f5_0         298 KB  conda-forge
#     libhwloc-2.10.0            |default_h5622ce7_1001         2.3 MB  conda-forge
#     libidn2-2.3.7              |       hd590300_0         124 KB  conda-forge
#     libopenvino-2024.2.0       |       h2da1b83_1         5.0 MB  conda-forge
#     libopenvino-auto-batch-plugin-2024.2.0|       hb045406_1         107 KB  conda-forge
#     libopenvino-auto-plugin-2024.2.0|       hb045406_1         226 KB  conda-forge
#     libopenvino-hetero-plugin-2024.2.0|       h5c03a75_1         188 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2024.2.0|       h2da1b83_1        10.6 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2024.2.0|       h2da1b83_1         8.2 MB  conda-forge
#     libopenvino-intel-npu-plugin-2024.2.0|       he02047a_1         336 KB  conda-forge
#     libopenvino-ir-frontend-2024.2.0|       h5c03a75_1         194 KB  conda-forge
#     libopenvino-onnx-frontend-2024.2.0|       h07e8aee_1         1.5 MB  conda-forge
#     libopenvino-paddle-frontend-2024.2.0|       h07e8aee_1         672 KB  conda-forge
#     libopenvino-pytorch-frontend-2024.2.0|       he02047a_1         1.1 MB  conda-forge
#     libopenvino-tensorflow-frontend-2024.2.0|       h39126c6_1         1.2 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2024.2.0|       he02047a_1         463 KB  conda-forge
#     libpciaccess-0.18          |       hd590300_0          28 KB  conda-forge
#     libtasn1-4.19.0            |       h166bdaf_0         114 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     libva-2.22.0               |       hb711507_0         205 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     nettle-3.9.1               |       h7ab15ed_0         988 KB  conda-forge
#     ocl-icd-2.3.2              |       hd590300_1         133 KB  conda-forge
#     openh264-2.4.1             |       h59595ed_0         718 KB  conda-forge
#     p11-kit-0.24.1             |       hc5aa10d_0         4.5 MB  conda-forge
#     pugixml-1.14               |       h59595ed_0         112 KB  conda-forge
#     svt-av1-2.1.0              |       hac33072_0         2.5 MB  conda-forge
#     tbb-2021.12.0              |       h297d8ca_1         190 KB  conda-forge
#     wayland-1.23.0             |       h5291e77_0         315 KB  conda-forge
#     wayland-protocols-1.36     |       hd8ed1ab_0          89 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        63.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.0.1-gpl_h3589c0a_102
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gnutls             conda-forge/linux-64::gnutls-3.7.9-hb077bed_0
#   libass             conda-forge/linux-64::libass-0.17.1-h8fe9dca_1
#   libdrm             conda-forge/linux-64::libdrm-2.4.122-h4ab18f5_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.10.0-default_h5622ce7_1001
#   libidn2            conda-forge/linux-64::libidn2-2.3.7-hd590300_0
#   libopenvino        conda-forge/linux-64::libopenvino-2024.2.0-h2da1b83_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2024.2.0-hb045406_1
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2024.2.0-hb045406_1
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2024.2.0-h5c03a75_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2024.2.0-h2da1b83_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2024.2.0-h2da1b83_1
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2024.2.0-he02047a_1
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2024.2.0-h5c03a75_1
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2024.2.0-h07e8aee_1
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2024.2.0-h07e8aee_1
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2024.2.0-he02047a_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2024.2.0-h39126c6_1
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2024.2.0-he02047a_1
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hd590300_0
#   libtasn1           conda-forge/linux-64::libtasn1-4.19.0-h166bdaf_0
#   libunistring       conda-forge/linux-64::libunistring-0.9.10-h7f98852_0
#   libva              conda-forge/linux-64::libva-2.22.0-hb711507_0
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   nettle             conda-forge/linux-64::nettle-3.9.1-h7ab15ed_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.2-hd590300_1
#   openh264           conda-forge/linux-64::openh264-2.4.1-h59595ed_0
#   p11-kit            conda-forge/linux-64::p11-kit-0.24.1-hc5aa10d_0
#   pugixml            conda-forge/linux-64::pugixml-1.14-h59595ed_0
#   svt-av1            conda-forge/linux-64::svt-av1-2.1.0-hac33072_0
#   tbb                conda-forge/linux-64::tbb-2021.12.0-h297d8ca_1
#   wayland            conda-forge/linux-64::wayland-1.23.0-h5291e77_0
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.36-hd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#
#
#
# Downloading and Extracting Packages:
# libopenvino-intel-cp | 10.6 MB   |                                       |   0%
# ffmpeg-7.0.1         | 9.6 MB    |                                       |   0%
#
# libopenvino-intel-gp | 8.2 MB    |                                       |   0%
#
#
# libopenvino-2024.2.0 | 5.0 MB    |                                       |   0%
#
#
#
# p11-kit-0.24.1       | 4.5 MB    |                                       |   0%
#
#
#
#
# x265-3.5             | 3.2 MB    |                                       |   0%
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    |                                       |   0%
#
#
#
#
#
#
# svt-av1-2.1.0        | 2.5 MB    |                                       |   0%
#
#
#
#
#
#
#
# libhwloc-2.10.0      | 2.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 742 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.4.1       | 718 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-paddle-f | 672 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 463 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 336 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wayland-1.23.0       | 315 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# libopenvino-2024.2.0 | 5.0 MB    | 1                                     |   0%
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | 1                                     |   0%
#
# libopenvino-intel-gp | 8.2 MB    |                                       |   0%
# libopenvino-intel-cp | 10.6 MB   |                                       |   0%
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | ############8                         |  35%
#
#
# libopenvino-2024.2.0 | 5.0 MB    | #########4                            |  26%
#
# libopenvino-intel-gp | 8.2 MB    | ######4                               |  17%
# libopenvino-intel-cp | 10.6 MB   | ###7                                  |  10%
#
# libopenvino-intel-gp | 8.2 MB    | ################################8     |  89%
# libopenvino-intel-cp | 10.6 MB   | ############################3         |  77%
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | 2                                     |   1%
#
#
#
#
# x265-3.5             | 3.2 MB    | 1                                     |   0%
#
#
#
#
#
#
# svt-av1-2.1.0        | 2.5 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
# libhwloc-2.10.0      | 2.3 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 742 KB    | 7                                     |   2%
#
#
# libopenvino-2024.2.0 | 5.0 MB    | ##################################### | 100%
#
#
# libopenvino-2024.2.0 | 5.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.4.1       | 718 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-paddle-f | 672 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 336 KB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 463 KB    | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wayland-1.23.0       | 315 KB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libopenvino-intel-gp | 8.2 MB    | ##################################### | 100%
#
#
#
#
#
# aom-3.9.1            | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
# libopenvino-intel-cp | 10.6 MB   | ##################################### | 100%
# ffmpeg-7.0.1         | 9.6 MB    | ##################################### | 100%
#
#
#
#
#
#
# svt-av1-2.1.0        | 2.5 MB    | ##################################### | 100%
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
# svt-av1-2.1.0        | 2.5 MB    | ##################################### | 100%
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libopenvino-onnx-fro | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libunistring-0.9.10  | 1.4 MB    | ##################################### | 100%
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.14.1        | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-pytorch- | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 742 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dav1d-1.2.1          | 742 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libhwloc-2.10.0      | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libhwloc-2.10.0      | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 336 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-np | 336 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-paddle-f | 672 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-paddle-f | 672 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wayland-1.23.0       | 315 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wayland-1.23.0       | 315 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.4.1       | 718 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.4.1       | 718 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 463 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-tensorfl | 463 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
